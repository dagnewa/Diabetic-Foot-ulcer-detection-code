# %%
from google.colab import drive
drive.mount('/content/drive')
import os

from platform import python_version
import warnings
import time
import datetime as dt
from sklearn.metrics import classification_report, confusion_matrix
import multiprocessing as mp
import shutil
from tensorflow.keras import applications
import matplotlib.pyplot as plt
import matplotlib.image as mpimg

import tensorflow as tf
from tensorflow.keras import backend as K
from tensorflow.keras.preprocessing.image import ImageDataGenerator
from tensorflow.keras.applications.mobilenet_v2 import MobileNetV2, preprocess_input, decode_predictions
from tensorflow.keras.models import *
from tensorflow.keras.layers import *
from tensorflow.keras.optimizers import *
from tensorflow.keras.utils import *
from tensorflow.keras.callbacks import *
from tensorflow.keras.initializers import *

import pandas as pd
import numpy as np
import seaborn as sn

from PIL import Image
import xml.etree.ElementTree as ET
import psutil
import random
import keras
from keras.datasets import cifar10
from keras.models import Model
from keras.layers import Dense, Dropout, Activation, BatchNormalization, Flatten
from keras.callbacks import ModelCheckpoint, ReduceLROnPlateau
from keras.optimizers import Adam
warnings.filterwarnings("ignore")
# %matplotlib inline
# Out:
# Mounted at /content/drive

# %%
epochs = 100
batch_size = 32
#testsplit = .2
targetx = 224
targety = 224
learning_rate = 0.0001
classes = 5
seed = random.randint(1, 1000)
dtrain_dir = '/content/drive/MyDrive/Diabetic Foot ulcer/Training'
valid_dir = '/content/drive/MyDrive/Diabetic Foot ulcer/Validation'

# %%
datagen = ImageDataGenerator(
        shear_range=0.1,
        #rescale=1./255,
        zoom_range=0.1,
        brightness_range=[0.9,1.1],
        horizontal_flip=True,
        preprocessing_function=preprocess_input
)

train_generator = datagen.flow_from_directory(
        dtrain_dir,
        target_size=(targetx, targety),
        batch_size=batch_size,
        class_mode='categorical',
        shuffle=True,
        seed=seed

)

validation_generator = datagen.flow_from_directory(
        valid_dir,
        target_size=(targetx, targety),
        batch_size=batch_size,
        class_mode='categorical',
        shuffle=False,
        seed=seed
)
# Out:
# Found 2600 images belonging to 5 classes.
# Found 554 images belonging to 5 classes.

# %%
checkpoint = ModelCheckpoint('MobileNetV2.keras',
                             monitor='val_accuracy',
                             save_best_only=True,
                             verbose=1,
                             mode='auto',
                             save_weights_only=False
                             )

#tensorboard = TensorBoard(log_dir="./logs-"+dt.datetime.now().strftime("%m%d%Y%H%M%S"),
                           # histogram_freq=0,
                            #batch_size=batch_size,
                            #write_graph=False,
                            #update_freq='epoch')

def epoch_end(epoch, logs):
    message = "End of epoch "+str(epoch)+". Learning rate: "+str(K.eval(model.optimizer.lr))
    os.system('echo '+message)

def epoch_begin(epoch, logs):
    print("Learning rate: ", K.eval(model.optimizer.lr))

def train_begin(logs):
    os.system("echo Beginning training")

earlystop = EarlyStopping(monitor='val_accuracy',
                          min_delta=.0001,
                          patience=50,
                          verbose=1,
                          mode='auto',
                          baseline=None,
                          restore_best_weights=True)

reducelr = ReduceLROnPlateau(monitor='val_accuracy',
                             factor=np.sqrt(.1),
                             patience=5,
                             verbose=1,
                             mode='auto',
                             min_delta=.0001,
                             cooldown=0,
                             min_lr=0.0000001)

lambdacb = LambdaCallback(on_epoch_begin=epoch_begin,
                          on_epoch_end=epoch_end,
                          on_batch_begin=None,
                          on_batch_end=None,
                          on_train_begin=train_begin,
                          on_train_end=None)

# %%
import keras
from keras.models import Model
from keras.layers import Dense, Dropout, Activation, BatchNormalization, Flatten
from keras.callbacks import ModelCheckpoint, ReduceLROnPlateau
from keras.optimizers import Adam

# %%
base_model = applications.DenseNet201(weights='imagenet', include_top=False, input_shape=(224, 224, 3))
for layer in base_model.layers:
    layer.trainable = False
x = base_model.output
x = GlobalAveragePooling2D()(x)
#x = Dropout(0.5)(x)
x = Dense(1280, activation='relu',  kernel_initializer=glorot_uniform(seed), bias_initializer='zeros')(x)
x = Dropout(0.5)(x)
predictions = Dense(classes, activation='softmax', kernel_initializer='random_uniform', bias_initializer='zeros')(x)

model = Model(inputs=base_model.input, outputs=predictions)
optimizer = Adam(learning_rate=learning_rate)
loss = "categorical_crossentropy"



model.compile(optimizer=optimizer,
              loss=loss,
              metrics=["accuracy"])
# Out:
# Downloading data from https://storage.googleapis.com/tensorflow/keras-applications/mobilenet_v2/mobilenet_v2_weights_tf_dim_ordering_tf_kernels_1.0_224_no_top.h5
# 9406464/9406464 ━━━━━━━━━━━━━━━━━━━━ 1s 0us/step

# %%
t=time.time()
history = model.fit(train_generator,

                                validation_data=validation_generator,

                                epochs=epochs,
                                callbacks=[reducelr])

#compute the training time
print('Training time: %s' % (time.time()-t))
# Out:
# Epoch 1/100
# 82/82 ━━━━━━━━━━━━━━━━━━━━ 1117s 13s/step - accuracy: 0.5474 - loss: 1.1311 - val_accuracy: 0.7690 - val_loss: 0.5988 - learning_rate: 1.0000e-04
# Epoch 2/100
# 82/82 ━━━━━━━━━━━━━━━━━━━━ 58s 661ms/step - accuracy: 0.7623 - loss: 0.6230 - val_accuracy: 0.8159 - val_loss: 0.4637 - learning_rate: 1.0000e-04
# Epoch 3/100
# 82/82 ━━━━━━━━━━━━━━━━━━━━ 58s 660ms/step - accuracy: 0.8121 - loss: 0.4835 - val_accuracy: 0.8863 - val_loss: 0.3819 - learning_rate: 1.0000e-04
# Epoch 4/100
# 82/82 ━━━━━━━━━━━━━━━━━━━━ 58s 660ms/step - accuracy: 0.8479 - loss: 0.4088 - val_accuracy: 0.8809 - val_loss: 0.3499 - learning_rate: 1.0000e-04
# Epoch 5/100
# 82/82 ━━━━━━━━━━━━━━━━━━━━ 57s 656ms/step - accuracy: 0.8755 - loss: 0.3619 - val_accuracy: 0.9116 - val_loss: 0.2941 - learning_rate: 1.0000e-04
# Epoch 6/100
# 82/82 ━━━━━━━━━━━━━━━━━━━━ 92s 781ms/step - accuracy: 0.8973 - loss: 0.2986 - val_accuracy: 0.9296 - val_loss: 0.2583 - learning_rate: 1.0000e-04
# Epoch 7/100
# 82/82 ━━━━━━━━━━━━━━━━━━━━ 57s 655ms/step - accuracy: 0.8979 - loss: 0.3126 - val_accuracy: 0.9440 - val_loss: 0.2121 - learning_rate: 1.0000e-04
# Epoch 8/100
# 82/82 ━━━━━━━━━━━━━━━━━━━━ 57s 655ms/step - accuracy: 0.9146 - loss: 0.2509 - val_accuracy: 0.9639 - val_loss: 0.1859 - learning_rate: 1.0000e-04
# Epoch 9/100
# 82/82 ━━━━━━━━━━━━━━━━━━━━ 57s 654ms/step - accuracy: 0.9247 - loss: 0.2338 - val_accuracy: 0.9747 - val_loss: 0.1684 - learning_rate: 1.0000e-04
# Epoch 10/100
# 82/82 ━━━━━━━━━━━━━━━━━━━━ 92s 779ms/step - accuracy: 0.9352 - loss: 0.2196 - val_accuracy: 0.9765 - val_loss: 0.1440 - learning_rate: 1.0000e-04
# Epoch 11/100
# 82/82 ━━━━━━━━━━━━━━━━━━━━ 57s 634ms/step - accuracy: 0.9440 - loss: 0.1835 - val_accuracy: 0.9801 - val_loss: 0.1322 - learning_rate: 1.0000e-04
# Epoch 12/100
# 82/82 ━━━━━━━━━━━━━━━━━━━━ 57s 637ms/step - accuracy: 0.9528 - loss: 0.1611 - val_accuracy: 0.9838 - val_loss: 0.1251 - learning_rate: 1.0000e-04
# Epoch 13/100
# 82/82 ━━━━━━━━━━━━━━━━━━━━ 58s 647ms/step - accuracy: 0.9586 - loss: 0.1615 - val_accuracy: 0.9801 - val_loss: 0.1210 - learning_rate: 1.0000e-04
# Epoch 14/100
# 82/82 ━━━━━━━━━━━━━━━━━━━━ 81s 634ms/step - accuracy: 0.9527 - loss: 0.1554 - val_accuracy: 0.9910 - val_loss: 0.0987 - learning_rate: 1.0000e-04
# Epoch 15/100
# 82/82 ━━━━━━━━━━━━━━━━━━━━ 84s 655ms/step - accuracy: 0.9617 - loss: 0.1380 - val_accuracy: 0.9910 - val_loss: 0.0916 - learning_rate: 1.0000e-04
# Epoch 16/100
# 82/82 ━━━━━━━━━━━━━━━━━━━━ 57s 631ms/step - accuracy: 0.9763 - loss: 0.1183 - val_accuracy: 0.9838 - val_loss: 0.0858 - learning_rate: 1.0000e-04
# Epoch 17/100
# 82/82 ━━━━━━━━━━━━━━━━━━━━ 82s 635ms/step - accuracy: 0.9700 - loss: 0.1101 - val_accuracy: 0.9910 - val_loss: 0.0747 - learning_rate: 1.0000e-04
# Epoch 18/100
# 82/82 ━━━━━━━━━━━━━━━━━━━━ 82s 635ms/step - accuracy: 0.9767 - loss: 0.0978 - val_accuracy: 0.9892 - val_loss: 0.0695 - learning_rate: 1.0000e-04
# Epoch 19/100
# 82/82 ━━━━━━━━━━━━━━━━━━━━ 60s 666ms/step - accuracy: 0.9768 - loss: 0.0976 - val_accuracy: 0.9946 - val_loss: 0.0620 - learning_rate: 1.0000e-04
# Epoch 20/100
# 82/82 ━━━━━━━━━━━━━━━━━━━━ 62s 705ms/step - accuracy: 0.9867 - loss: 0.0800 - val_accuracy: 0.9964 - val_loss: 0.0539 - learning_rate: 1.0000e-04
# Epoch 21/100
# 82/82 ━━━━━━━━━━━━━━━━━━━━ 79s 672ms/step - accuracy: 0.9847 - loss: 0.0762 - val_accuracy: 0.9946 - val_loss: 0.0570 - learning_rate: 1.0000e-04
# Epoch 22/100
# 82/82 ━━━━━━━━━━━━━━━━━━━━ 62s 687ms/step - accuracy: 0.9792 - loss: 0.0794 - val_accuracy: 0.9964 - val_loss: 0.0490 - learning_rate: 1.0000e-04
# Epoch 23/100
# 82/82 ━━━━━━━━━━━━━━━━━━━━ 61s 691ms/step - accuracy: 0.9897 - loss: 0.0662 - val_accuracy: 0.9982 - val_loss: 0.0470 - learning_rate: 1.0000e-04
# Epoch 24/100
# 82/82 ━━━━━━━━━━━━━━━━━━━━ 61s 699ms/step - accuracy: 0.9862 - loss: 0.0640 - val_accuracy: 0.9964 - val_loss: 0.0426 - learning_rate: 1.0000e-04
# Epoch 25/100
# 82/82 ━━━━━━━━━━━━━━━━━━━━ 61s 702ms/step - accuracy: 0.9867 - loss: 0.0656 - val_accuracy: 0.9946 - val_loss: 0.0396 - learning_rate: 1.0000e-04
# Epoch 26/100
# 82/82 ━━━━━━━━━━━━━━━━━━━━ 80s 683ms/step - accuracy: 0.9890 - loss: 0.0567 - val_accuracy: 0.9982 - val_loss: 0.0345 - learning_rate: 1.0000e-04
# Epoch 27/100
# 82/82 ━━━━━━━━━━━━━━━━━━━━ 69s 800ms/step - accuracy: 0.9908 - loss: 0.0581 - val_accuracy: 1.0000 - val_loss: 0.0311 - learning_rate: 1.0000e-04
# Epoch 28/100
# 82/82 ━━━━━━━━━━━━━━━━━━━━ 73s 689ms/step - accuracy: 0.9939 - loss: 0.0502 - val_accuracy: 1.0000 - val_loss: 0.0271 - learning_rate: 1.0000e-04
# Epoch 29/100
# 82/82 ━━━━━━━━━━━━━━━━━━━━ 84s 701ms/step - accuracy: 0.9967 - loss: 0.0436 - val_accuracy: 0.9982 - val_loss: 0.0271 - learning_rate: 1.0000e-04
# Epoch 30/100
# 82/82 ━━━━━━━━━━━━━━━━━━━━ 79s 663ms/step - accuracy: 0.9868 - loss: 0.0506 - val_accuracy: 1.0000 - val_loss: 0.0264 - learning_rate: 1.0000e-04
# Epoch 31/100
# 82/82 ━━━━━━━━━━━━━━━━━━━━ 60s 668ms/step - accuracy: 0.9945 - loss: 0.0353 - val_accuracy: 1.0000 - val_loss: 0.0228 - learning_rate: 1.0000e-04
# Epoch 32/100
# 81/82 ━━━━━━━━━━━━━━━━━━━━ 0s 553ms/step - accuracy: 0.9926 - loss: 0.0393
# Epoch 32: ReduceLROnPlateau reducing learning rate to 3.1622775802825264e-05.
# 82/82 ━━━━━━━━━━━━━━━━━━━━ 81s 658ms/step - accuracy: 0.9926 - loss: 0.0393 - val_accuracy: 1.0000 - val_loss: 0.0200 - learning_rate: 1.0000e-04
# Epoch 33/100
# 82/82 ━━━━━━━━━━━━━━━━━━━━ 60s 670ms/step - accuracy: 0.9975 - loss: 0.0334 - val_accuracy: 1.0000 - val_loss: 0.0213 - learning_rate: 3.1623e-05
# Epoch 34/100
# 82/82 ━━━━━━━━━━━━━━━━━━━━ 83s 683ms/step - accuracy: 0.9970 - loss: 0.0317 - val_accuracy: 1.0000 - val_loss: 0.0191 - learning_rate: 3.1623e-05
# Epoch 35/100
# 82/82 ━━━━━━━━━━━━━━━━━━━━ 81s 673ms/step - accuracy: 0.9976 - loss: 0.0297 - val_accuracy: 1.0000 - val_loss: 0.0185 - learning_rate: 3.1623e-05
# Epoch 36/100
# 82/82 ━━━━━━━━━━━━━━━━━━━━ 59s 656ms/step - accuracy: 0.9994 - loss: 0.0274 - val_accuracy: 1.0000 - val_loss: 0.0181 - learning_rate: 3.1623e-05
# Epoch 37/100
# 81/82 ━━━━━━━━━━━━━━━━━━━━ 0s 583ms/step - accuracy: 0.9948 - loss: 0.0303
# Epoch 37: ReduceLROnPlateau reducing learning rate to 9.999999259090306e-06.
# 82/82 ━━━━━━━━━━━━━━━━━━━━ 84s 692ms/step - accuracy: 0.9948 - loss: 0.0303 - val_accuracy: 1.0000 - val_loss: 0.0140 - learning_rate: 3.1623e-05
# Epoch 38/100
# 82/82 ━━━━━━━━━━━━━━━━━━━━ 82s 707ms/step - accuracy: 0.9990 - loss: 0.0257 - val_accuracy: 1.0000 - val_loss: 0.0176 - learning_rate: 1.0000e-05
# Epoch 39/100
# 82/82 ━━━━━━━━━━━━━━━━━━━━ 63s 710ms/step - accuracy: 0.9967 - loss: 0.0292 - val_accuracy: 1.0000 - val_loss: 0.0159 - learning_rate: 1.0000e-05
# Epoch 40/100
# 82/82 ━━━━━━━━━━━━━━━━━━━━ 71s 810ms/step - accuracy: 0.9984 - loss: 0.0264 - val_accuracy: 0.9982 - val_loss: 0.0200 - learning_rate: 1.0000e-05
# Epoch 41/100
# 82/82 ━━━━━━━━━━━━━━━━━━━━ 72s 675ms/step - accuracy: 0.9976 - loss: 0.0236 - val_accuracy: 1.0000 - val_loss: 0.0174 - learning_rate: 1.0000e-05
# Epoch 42/100
# 81/82 ━━━━━━━━━━━━━━━━━━━━ 0s 555ms/step - accuracy: 0.9948 - loss: 0.0269
# Epoch 42: ReduceLROnPlateau reducing learning rate to 3.162277292675049e-06.
# 82/82 ━━━━━━━━━━━━━━━━━━━━ 81s 674ms/step - accuracy: 0.9948 - loss: 0.0270 - val_accuracy: 1.0000 - val_loss: 0.0168 - learning_rate: 1.0000e-05
# Epoch 43/100
# 82/82 ━━━━━━━━━━━━━━━━━━━━ 60s 682ms/step - accuracy: 0.9960 - loss: 0.0282 - val_accuracy: 1.0000 - val_loss: 0.0149 - learning_rate: 3.1623e-06
# Epoch 44/100
# 82/82 ━━━━━━━━━━━━━━━━━━━━ 80s 674ms/step - accuracy: 0.9973 - loss: 0.0253 - val_accuracy: 1.0000 - val_loss: 0.0175 - learning_rate: 3.1623e-06
# Epoch 45/100
# 82/82 ━━━━━━━━━━━━━━━━━━━━ 82s 678ms/step - accuracy: 0.9960 - loss: 0.0254 - val_accuracy: 0.9982 - val_loss: 0.0166 - learning_rate: 3.1623e-06
# Epoch 46/100
# 82/82 ━━━━━━━━━━━━━━━━━━━━ 58s 667ms/step - accuracy: 0.9968 - loss: 0.0267 - val_accuracy: 1.0000 - val_loss: 0.0133 - learning_rate: 3.1623e-06
# Epoch 47/100
# 81/82 ━━━━━━━━━━━━━━━━━━━━ 0s 544ms/step - accuracy: 0.9974 - loss: 0.0303
# Epoch 47: ReduceLROnPlateau reducing learning rate to 9.999999115286567e-07.
# 82/82 ━━━━━━━━━━━━━━━━━━━━ 92s 791ms/step - accuracy: 0.9973 - loss: 0.0303 - val_accuracy: 1.0000 - val_loss: 0.0150 - learning_rate: 3.1623e-06
# Epoch 48/100
# 82/82 ━━━━━━━━━━━━━━━━━━━━ 82s 790ms/step - accuracy: 0.9958 - loss: 0.0273 - val_accuracy: 1.0000 - val_loss: 0.0139 - learning_rate: 1.0000e-06
# Epoch 49/100
# 82/82 ━━━━━━━━━━━━━━━━━━━━ 73s 677ms/step - accuracy: 0.9980 - loss: 0.0273 - val_accuracy: 1.0000 - val_loss: 0.0157 - learning_rate: 1.0000e-06
# Epoch 50/100
# 82/82 ━━━━━━━━━━━━━━━━━━━━ 58s 667ms/step - accuracy: 0.9984 - loss: 0.0235 - val_accuracy: 1.0000 - val_loss: 0.0160 - learning_rate: 1.0000e-06
# Epoch 51/100
# 82/82 ━━━━━━━━━━━━━━━━━━━━ 81s 660ms/step - accuracy: 0.9972 - loss: 0.0240 - val_accuracy: 0.9982 - val_loss: 0.0176 - learning_rate: 1.0000e-06
# Epoch 52/100
# 81/82 ━━━━━━━━━━━━━━━━━━━━ 0s 540ms/step - accuracy: 0.9981 - loss: 0.0286
# Epoch 52: ReduceLROnPlateau reducing learning rate to 3.1622772926750485e-07.
# 82/82 ━━━━━━━━━━━━━━━━━━━━ 82s 662ms/step - accuracy: 0.9980 - loss: 0.0286 - val_accuracy: 1.0000 - val_loss: 0.0152 - learning_rate: 1.0000e-06
# Epoch 53/100
# 82/82 ━━━━━━━━━━━━━━━━━━━━ 58s 665ms/step - accuracy: 0.9973 - loss: 0.0277 - val_accuracy: 1.0000 - val_loss: 0.0167 - learning_rate: 3.1623e-07
# Epoch 54/100
# 82/82 ━━━━━━━━━━━━━━━━━━━━ 81s 659ms/step - accuracy: 0.9968 - loss: 0.0269 - val_accuracy: 1.0000 - val_loss: 0.0140 - learning_rate: 3.1623e-07
# Epoch 55/100
# 82/82 ━━━━━━━━━━━━━━━━━━━━ 57s 659ms/step - accuracy: 0.9967 - loss: 0.0248 - val_accuracy: 1.0000 - val_loss: 0.0144 - learning_rate: 3.1623e-07
# Epoch 56/100
# 82/82 ━━━━━━━━━━━━━━━━━━━━ 94s 810ms/step - accuracy: 0.9979 - loss: 0.0274 - val_accuracy: 1.0000 - val_loss: 0.0141 - learning_rate: 3.1623e-07
# Epoch 57/100
# 81/82 ━━━━━━━━━━━━━━━━━━━━ 0s 534ms/step - accuracy: 0.9947 - loss: 0.0275
# Epoch 57: ReduceLROnPlateau reducing learning rate to 1e-07.
# 82/82 ━━━━━━━━━━━━━━━━━━━━ 57s 657ms/step - accuracy: 0.9947 - loss: 0.0275 - val_accuracy: 1.0000 - val_loss: 0.0164 - learning_rate: 3.1623e-07
# Epoch 58/100
# 82/82 ━━━━━━━━━━━━━━━━━━━━ 57s 663ms/step - accuracy: 0.9979 - loss: 0.0236 - val_accuracy: 1.0000 - val_loss: 0.0145 - learning_rate: 1.0000e-07
# Epoch 59/100
# 82/82 ━━━━━━━━━━━━━━━━━━━━ 57s 656ms/step - accuracy: 0.9964 - loss: 0.0269 - val_accuracy: 1.0000 - val_loss: 0.0152 - learning_rate: 1.0000e-07
# Epoch 60/100
# 82/82 ━━━━━━━━━━━━━━━━━━━━ 82s 659ms/step - accuracy: 0.9959 - loss: 0.0290 - val_accuracy: 1.0000 - val_loss: 0.0135 - learning_rate: 1.0000e-07
# Epoch 61/100
# 82/82 ━━━━━━━━━━━━━━━━━━━━ 92s 781ms/step - accuracy: 0.9982 - loss: 0.0247 - val_accuracy: 1.0000 - val_loss: 0.0165 - learning_rate: 1.0000e-07
# Epoch 62/100
# 82/82 ━━━━━━━━━━━━━━━━━━━━ 82s 788ms/step - accuracy: 0.9986 - loss: 0.0270 - val_accuracy: 1.0000 - val_loss: 0.0149 - learning_rate: 1.0000e-07
# Epoch 63/100
# 82/82 ━━━━━━━━━━━━━━━━━━━━ 57s 639ms/step - accuracy: 0.9988 - loss: 0.0216 - val_accuracy: 1.0000 - val_loss: 0.0156 - learning_rate: 1.0000e-07
# Epoch 64/100
# 82/82 ━━━━━━━━━━━━━━━━━━━━ 82s 641ms/step - accuracy: 0.9971 - loss: 0.0255 - val_accuracy: 1.0000 - val_loss: 0.0146 - learning_rate: 1.0000e-07
# Epoch 65/100
# 82/82 ━━━━━━━━━━━━━━━━━━━━ 82s 647ms/step - accuracy: 0.9980 - loss: 0.0220 - val_accuracy: 1.0000 - val_loss: 0.0139 - learning_rate: 1.0000e-07
# Epoch 66/100
# 82/82 ━━━━━━━━━━━━━━━━━━━━ 82s 649ms/step - accuracy: 0.9992 - loss: 0.0255 - val_accuracy: 1.0000 - val_loss: 0.0158 - learning_rate: 1.0000e-07
# Epoch 67/100
# 82/82 ━━━━━━━━━━━━━━━━━━━━ 82s 646ms/step - accuracy: 0.9982 - loss: 0.0259 - val_accuracy: 1.0000 - val_loss: 0.0158 - learning_rate: 1.0000e-07
# Epoch 68/100
# 82/82 ━━━━━━━━━━━━━━━━━━━━ 57s 640ms/step - accuracy: 0.9984 - loss: 0.0266 - val_accuracy: 1.0000 - val_loss: 0.0128 - learning_rate: 1.0000e-07
# Epoch 69/100
# 82/82 ━━━━━━━━━━━━━━━━━━━━ 61s 679ms/step - accuracy: 0.9964 - loss: 0.0255 - val_accuracy: 1.0000 - val_loss: 0.0140 - learning_rate: 1.0000e-07
# Epoch 70/100
# 82/82 ━━━━━━━━━━━━━━━━━━━━ 69s 789ms/step - accuracy: 0.9986 - loss: 0.0255 - val_accuracy: 0.9982 - val_loss: 0.0181 - learning_rate: 1.0000e-07
# Epoch 71/100
# 82/82 ━━━━━━━━━━━━━━━━━━━━ 59s 659ms/step - accuracy: 0.9989 - loss: 0.0249 - val_accuracy: 1.0000 - val_loss: 0.0132 - learning_rate: 1.0000e-07
# Epoch 72/100
# 82/82 ━━━━━━━━━━━━━━━━━━━━ 80s 641ms/step - accuracy: 0.9958 - loss: 0.0277 - val_accuracy: 0.9982 - val_loss: 0.0145 - learning_rate: 1.0000e-07
# Epoch 73/100
# 82/82 ━━━━━━━━━━━━━━━━━━━━ 82s 645ms/step - accuracy: 0.9986 - loss: 0.0243 - val_accuracy: 1.0000 - val_loss: 0.0181 - learning_rate: 1.0000e-07
# Epoch 74/100
# 82/82 ━━━━━━━━━━━━━━━━━━━━ 61s 691ms/step - accuracy: 0.9961 - loss: 0.0273 - val_accuracy: 1.0000 - val_loss: 0.0160 - learning_rate: 1.0000e-07
# Epoch 75/100
# 82/82 ━━━━━━━━━━━━━━━━━━━━ 58s 653ms/step - accuracy: 0.9985 - loss: 0.0222 - val_accuracy: 0.9982 - val_loss: 0.0198 - learning_rate: 1.0000e-07
# Epoch 76/100
# 82/82 ━━━━━━━━━━━━━━━━━━━━ 82s 655ms/step - accuracy: 0.9967 - loss: 0.0274 - val_accuracy: 1.0000 - val_loss: 0.0140 - learning_rate: 1.0000e-07
# Epoch 77/100
# 82/82 ━━━━━━━━━━━━━━━━━━━━ 57s 645ms/step - accuracy: 0.9991 - loss: 0.0250 - val_accuracy: 1.0000 - val_loss: 0.0159 - learning_rate: 1.0000e-07
# Epoch 78/100
# 82/82 ━━━━━━━━━━━━━━━━━━━━ 58s 653ms/step - accuracy: 0.9980 - loss: 0.0276 - val_accuracy: 1.0000 - val_loss: 0.0158 - learning_rate: 1.0000e-07
# Epoch 79/100
# 82/82 ━━━━━━━━━━━━━━━━━━━━ 86s 710ms/step - accuracy: 0.9959 - loss: 0.0258 - val_accuracy: 1.0000 - val_loss: 0.0151 - learning_rate: 1.0000e-07
# Epoch 80/100
# 82/82 ━━━━━━━━━━━━━━━━━━━━ 80s 684ms/step - accuracy: 0.9982 - loss: 0.0253 - val_accuracy: 1.0000 - val_loss: 0.0155 - learning_rate: 1.0000e-07
# Epoch 81/100
# 82/82 ━━━━━━━━━━━━━━━━━━━━ 82s 694ms/step - accuracy: 0.9951 - loss: 0.0295 - val_accuracy: 1.0000 - val_loss: 0.0139 - learning_rate: 1.0000e-07
# Epoch 82/100
# 82/82 ━━━━━━━━━━━━━━━━━━━━ 60s 686ms/step - accuracy: 0.9965 - loss: 0.0248 - val_accuracy: 1.0000 - val_loss: 0.0153 - learning_rate: 1.0000e-07
# Epoch 83/100
# 82/82 ━━━━━━━━━━━━━━━━━━━━ 82s 690ms/step - accuracy: 0.9983 - loss: 0.0281 - val_accuracy: 1.0000 - val_loss: 0.0169 - learning_rate: 1.0000e-07
# Epoch 84/100
# 82/82 ━━━━━━━━━━━━━━━━━━━━ 63s 722ms/step - accuracy: 0.9975 - loss: 0.0250 - val_accuracy: 1.0000 - val_loss: 0.0144 - learning_rate: 1.0000e-07
# Epoch 85/100
# 82/82 ━━━━━━━━━━━━━━━━━━━━ 61s 676ms/step - accuracy: 0.9964 - loss: 0.0274 - val_accuracy: 1.0000 - val_loss: 0.0146 - learning_rate: 1.0000e-07
# Epoch 86/100
# 82/82 ━━━━━━━━━━━━━━━━━━━━ 79s 666ms/step - accuracy: 0.9969 - loss: 0.0258 - val_accuracy: 1.0000 - val_loss: 0.0172 - learning_rate: 1.0000e-07
# Epoch 87/100
# 82/82 ━━━━━━━━━━━━━━━━━━━━ 81s 657ms/step - accuracy: 0.9988 - loss: 0.0255 - val_accuracy: 1.0000 - val_loss: 0.0155 - learning_rate: 1.0000e-07
# Epoch 88/100
# 82/82 ━━━━━━━━━━━━━━━━━━━━ 58s 661ms/step - accuracy: 0.9962 - loss: 0.0260 - val_accuracy: 1.0000 - val_loss: 0.0152 - learning_rate: 1.0000e-07
# Epoch 89/100
# 82/82 ━━━━━━━━━━━━━━━━━━━━ 59s 680ms/step - accuracy: 0.9972 - loss: 0.0255 - val_accuracy: 1.0000 - val_loss: 0.0175 - learning_rate: 1.0000e-07
# Epoch 90/100
# 82/82 ━━━━━━━━━━━━━━━━━━━━ 57s 663ms/step - accuracy: 0.9959 - loss: 0.0259 - val_accuracy: 1.0000 - val_loss: 0.0143 - learning_rate: 1.0000e-07
# Epoch 91/100
# 82/82 ━━━━━━━━━━━━━━━━━━━━ 59s 686ms/step - accuracy: 0.9956 - loss: 0.0269 - val_accuracy: 1.0000 - val_loss: 0.0146 - learning_rate: 1.0000e-07
# Epoch 92/100
# 82/82 ━━━━━━━━━━━━━━━━━━━━ 69s 801ms/step - accuracy: 0.9991 - loss: 0.0263 - val_accuracy: 1.0000 - val_loss: 0.0157 - learning_rate: 1.0000e-07
# Epoch 93/100
# 82/82 ━━━━━━━━━━━━━━━━━━━━ 59s 676ms/step - accuracy: 0.9967 - loss: 0.0255 - val_accuracy: 1.0000 - val_loss: 0.0135 - learning_rate: 1.0000e-07
# Epoch 94/100
# 82/82 ━━━━━━━━━━━━━━━━━━━━ 82s 682ms/step - accuracy: 0.9975 - loss: 0.0264 - val_accuracy: 1.0000 - val_loss: 0.0136 - learning_rate: 1.0000e-07
# Epoch 95/100
# 82/82 ━━━━━━━━━━━━━━━━━━━━ 57s 658ms/step - accuracy: 0.9985 - loss: 0.0212 - val_accuracy: 1.0000 - val_loss: 0.0161 - learning_rate: 1.0000e-07
# Epoch 96/100
# 82/82 ━━━━━━━━━━━━━━━━━━━━ 92s 781ms/step - accuracy: 0.9977 - loss: 0.0250 - val_accuracy: 1.0000 - val_loss: 0.0156 - learning_rate: 1.0000e-07
# Epoch 97/100
# 82/82 ━━━━━━━━━━━━━━━━━━━━ 82s 781ms/step - accuracy: 0.9957 - loss: 0.0252 - val_accuracy: 1.0000 - val_loss: 0.0153 - learning_rate: 1.0000e-07
# Epoch 98/100
# 82/82 ━━━━━━━━━━━━━━━━━━━━ 68s 785ms/step - accuracy: 0.9960 - loss: 0.0295 - val_accuracy: 1.0000 - val_loss: 0.0157 - learning_rate: 1.0000e-07
# Epoch 99/100
# 82/82 ━━━━━━━━━━━━━━━━━━━━ 71s 651ms/step - accuracy: 0.9991 - loss: 0.0243 - val_accuracy: 1.0000 - val_loss: 0.0144 - learning_rate: 1.0000e-07
# Epoch 100/100
# 82/82 ━━━━━━━━━━━━━━━━━━━━ 92s 786ms/step - accuracy: 0.9969 - loss: 0.0260 - val_accuracy: 1.0000 - val_loss: 0.0172 - learning_rate: 1.0000e-07
# Training time: 8156.639922618866

# %%
 import matplotlib.pyplot as plt
# Config the matplotlib backend as plotting inline in IPython
# %matplotlib inline

acc = history.history['val_accuracy']
val_acc = history.history['accuracy']
val_loss = history.history['loss']
loss = history.history['val_loss']
epochs = range(1, len(acc) + 1)
plt.style.use('seaborn')

plt.plot(epochs, acc, label='Training acc')
plt.plot(epochs, val_acc, label='Validation acc')
plt.xlabel('Num of Epochs')
plt.ylabel('Accuracy')
plt.title(' MobileNetV2 Training vs validation accuracy ')
plt.legend()
plt.figure()
plt.plot(epochs, loss, label='Training loss')
plt.plot(epochs, val_loss, label='Validation loss')
plt.title('MobileNetV2 Training vs validation loss ')
plt.xlabel('Num of Epochs')
plt.ylabel('Loss')
plt.legend()
plt.show()

# %%
model.save("/content/drive/MyDrive/Diabetic Foot ulcer/deployment_model.h5")
print("model saved!!!")
# Out:
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.
# model saved!!!

# %%
import numpy as np
accuracy = np.array(acc)
print(' Training Accuracy of model is      :   '  , accuracy[-1]*100,'%' )

val_accuracy = np.array(val_acc)
print('  Validation  Accuracy of model is      :   '  , val_accuracy[-1]*100,'%' )

t_loss = np.array(loss)
print('training   loss of   model   is     :   ' , t_loss[-1]*100,'%')
val_loss = np.array(val_loss)
print('Validation  loss of   model  is     :   ' , val_loss[-1]*100,'%')
# Out:
#  Training Accuracy of model is      :    100.0 %
#   Validation  Accuracy of model is      :    99.73077178001404 %
# training   loss of   model   is     :    1.7200591042637825 %
# Validation  loss of   model  is     :    2.461395598948002 %

# %%
data_dir1 = "/content/drive/MyDrive/Diabetic Foot ulcer/Testing"

datagen = ImageDataGenerator(
        shear_range=0.1,
        zoom_range=0.1,
        brightness_range=[0.9,1.1],
        horizontal_flip=True,
        preprocessing_function=preprocess_input
)
val_suffle=False

test_generator = datagen.flow_from_directory(
        data_dir1,
        target_size=(224, 224),
        batch_size=32,
        class_mode='categorical',
        shuffle=False,

        #subset="test"
)
score = model.evaluate(test_generator, verbose=1)
print(score)
# Out:
# Found 555 images belonging to 5 classes.
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 199s 12s/step - accuracy: 0.9988 - loss: 0.0172
# [0.028829896822571754, 0.9963964223861694]

# %%
from sklearn.metrics import roc_auc_score,roc_curve,auc
import seaborn as sns
import pandas as pd
import numpy as np
import seaborn as sn
def plot_multiclass_roc(y_pred, y_test, n_classes,class_label, figsize=(17, 6)):

    # structures
    fpr = dict()
    tpr = dict()
    roc_auc = dict()

    # calculate dummies once
    for i in range(n_classes):
        fpr[i], tpr[i], _ = roc_curve(y_test.iloc[:, i], y_pred[:, i])
        roc_auc[i] = auc(fpr[i], tpr[i])

    # roc for each class
    fig, ax = plt.subplots(figsize=figsize)
    ax.plot([0, 1], [0, 1], 'k--')
    ax.set_xlim([0.0, 1.0])
    ax.set_ylim([0.0, 1.05])
    ax.set_xlabel('False Positive Rate')
    ax.set_ylabel('True Positive Rate')
    ax.set_title('Receiver operating characteristic example')
    for i,j in enumerate(class_label):
        print(i,j)
        ax.plot(fpr[i], tpr[i], label='ROC curve (area = {}) for label {}'.format(np.round(roc_auc[i],2),j))
    ax.legend(loc="best")
    ax.grid(alpha=.4)
    sns.despine()
    plt.show()

# %%
#Alexnet_model.evaluate(valid_set,steps=valid_set.n//batch_size)
#valid_set.reset()

model.evaluate(test,steps=test_generator.n//batch_size)
test_generator.reset()

y_pred = model.predict(test_generator, steps=int(np.ceil(test_generator.n / batch_size)), verbose=1)
class_label=list(test_generator.class_indices.keys())


if val_suffle==True:
  per = np.random.permutation(test_generator.n)
  test_generator.index_array = per
  y_true = test_generator.classes[per]
else:
  y_true = test_generator.classes


plot_multiclass_roc(y_pred, pd.get_dummies(y_true), n_classes=5, class_label=class_label, figsize=(10, 5))
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-14-3a648e56ceee> in <cell line: 4>()
#       2 #valid_set.reset()
#       3
# ----> 4 model.evaluate(test,steps=test_generator.n//batch_size)
#       5 test_generator.reset()
#       6
#
# NameError: name 'test' is not defined

# %%
score = model.evaluate(test_generator, verbose=1)
# Out:
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 9s 483ms/step - accuracy: 0.9993 - loss: 0.0153

# %%
test_generator.reset()
predictions = model.predict(test_generator, steps=len(test_generator))
y = np.argmax(predictions, axis=1)

print('Classification Report')
cr = classification_report(y_true=test_generator.classes, y_pred=y, target_names=test_generator.class_indices)
print(cr)
# Out:
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 10s 543ms/step
# Classification Report
#                                  precision    recall  f1-score   support
#
#             Grade_0 Intact skin       1.00      1.00      1.00       111
#       Grade_1 Superficial ulcer       1.00      1.00      1.00       111
#    Grade_2 Deep ulcer to tendon       1.00      1.00      1.00       111
# Grade_3 Deep ulcer with abscess       1.00      1.00      1.00       111
#     Grade_4 Whole foot gangrene       1.00      1.00      1.00       111
#
#                        accuracy                           1.00       555
#                       macro avg       1.00      1.00      1.00       555
#                    weighted avg       1.00      1.00      1.00       555

# %%
import seaborn as sns
from sklearn.metrics import confusion_matrix, classification_report
classes=['Grade_0 Intact skin', 'Grade_1 Superficial ulcer', 'Grade_2 Deep ulcer to tendon','Grade_3 Deep ulcer with absces','Grade_4 Whole foot gangrene']

preds=model.predict(test_generator)
y_pred=[]
y_true=[]
for i, p in enumerate(preds):
    y_pred.append(np.argmax(p))
    y_true.append(test_generator.labels[i])
y_pred=np.array(y_pred)
y_true=np.array(y_true)
cm = confusion_matrix(y_true, y_pred )
clr = classification_report(y_true, y_pred, target_names=classes)
length=len(classes)
plt.figure(figsize=(8, 8))
sns.heatmap(cm, annot=True, vmin=0, fmt='g', cmap='Blues', cbar=False)
plt.xticks(np.arange(length)+.5, classes, rotation= 90)
plt.yticks(np.arange(length)+.5, classes, rotation=0)
plt.xlabel("Predicted")
plt.ylabel("Actual ")
plt.title("Confusion Matrix")
plt.show()
# Out:
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 9s 456ms/step
