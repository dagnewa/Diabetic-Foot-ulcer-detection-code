# %%
from google.colab import drive
drive.mount('/content/drive')
import os

from platform import python_version
import warnings
import time
import datetime as dt
from sklearn.metrics import classification_report, confusion_matrix
import multiprocessing as mp
import shutil
from tensorflow.keras import applications
import matplotlib.pyplot as plt
import matplotlib.image as mpimg

import tensorflow as tf
from tensorflow.keras import backend as K
from tensorflow.keras.preprocessing.image import ImageDataGenerator
from tensorflow.keras.applications.mobilenet_v2 import MobileNetV2, preprocess_input, decode_predictions
from tensorflow.keras.models import *
from tensorflow.keras.layers import *
from tensorflow.keras.optimizers import *
from tensorflow.keras.utils import *
from tensorflow.keras.callbacks import *
from tensorflow.keras.initializers import *

import pandas as pd
import numpy as np
import seaborn as sn

from PIL import Image
import xml.etree.ElementTree as ET
import psutil
import random
import keras
from keras.datasets import cifar10
from keras.models import Model
from keras.layers import Dense, Dropout, Activation, BatchNormalization, Flatten
from keras.callbacks import ModelCheckpoint, ReduceLROnPlateau
from keras.optimizers import Adam
warnings.filterwarnings("ignore")
# %matplotlib inline
# Out:
# Mounted at /content/drive

# %%
epochs = 100
batch_size = 32
#testsplit = .2
targetx = 224
targety = 224
learning_rate = 0.0001
classes = 5
seed = random.randint(1, 1000)
dtrain_dir = '/content/drive/MyDrive/Diabetic Foot ulcer/Training'
valid_dir = '/content/drive/MyDrive/Diabetic Foot ulcer/Validation'

# %%
datagen = ImageDataGenerator(
        shear_range=0.1,
        #rescale=1./255,
        zoom_range=0.1,
        brightness_range=[0.9,1.1],
        horizontal_flip=True,
        preprocessing_function=preprocess_input
)

train_generator = datagen.flow_from_directory(
        dtrain_dir,
        target_size=(targetx, targety),
        batch_size=batch_size,
        class_mode='categorical',
        shuffle=True,
        seed=seed

)

validation_generator = datagen.flow_from_directory(
        valid_dir,
        target_size=(targetx, targety),
        batch_size=batch_size,
        class_mode='categorical',
        shuffle=True,
        seed=seed
)
# Out:
# Found 2600 images belonging to 5 classes.
# Found 554 images belonging to 5 classes.

# %%
checkpoint = ModelCheckpoint('MobileNetV2.keras',
                             monitor='val_accuracy',
                             save_best_only=True,
                             verbose=1,
                             mode='auto',
                             save_weights_only=False
                             )

#tensorboard = TensorBoard(log_dir="./logs-"+dt.datetime.now().strftime("%m%d%Y%H%M%S"),
                           # histogram_freq=0,
                            #batch_size=batch_size,
                            #write_graph=False,
                            #update_freq='epoch')

def epoch_end(epoch, logs):
    message = "End of epoch "+str(epoch)+". Learning rate: "+str(K.eval(model.optimizer.lr))
    os.system('echo '+message)

def epoch_begin(epoch, logs):
    print("Learning rate: ", K.eval(model.optimizer.lr))

def train_begin(logs):
    os.system("echo Beginning training")

earlystop = EarlyStopping(monitor='val_accuracy',
                          min_delta=.0001,
                          patience=50,
                          verbose=1,
                          mode='auto',
                          baseline=None,
                          restore_best_weights=True)

reducelr = ReduceLROnPlateau(monitor='val_accuracy',
                             factor=np.sqrt(.1),
                             patience=5,
                             verbose=1,
                             mode='auto',
                             min_delta=.0001,
                             cooldown=0,
                             min_lr=0.0000001)

lambdacb = LambdaCallback(on_epoch_begin=epoch_begin,
                          on_epoch_end=epoch_end,
                          on_batch_begin=None,
                          on_batch_end=None,
                          on_train_begin=train_begin,
                          on_train_end=None)

# %%
import keras
from keras.models import Model
from keras.layers import Dense, Dropout, Activation, BatchNormalization, Flatten
from keras.callbacks import ModelCheckpoint, ReduceLROnPlateau
from keras.optimizers import Adam

# %%
base_model = applications.DenseNet201(weights='imagenet', include_top=False, input_shape=(224, 224, 3))
for layer in base_model.layers:
    layer.trainable = False
x = base_model.output
x = GlobalAveragePooling2D()(x)
x = Dropout(0.1)(x)
x = Dense(1280, activation='relu',  kernel_initializer=glorot_uniform(seed), bias_initializer='zeros')(x)
x = Dropout(0.5)(x)
predictions = Dense(classes, activation='softmax', kernel_initializer='random_uniform', bias_initializer='zeros')(x)

model = Model(inputs=base_model.input, outputs=predictions)
optimizer = Adam(learning_rate=learning_rate)
loss = "categorical_crossentropy"



model.compile(optimizer=optimizer,
              loss=loss,
              metrics=["accuracy"])

# %%
t=time.time()
history = model.fit(train_generator,

                                validation_data=validation_generator,

                                epochs=epochs,
                                callbacks=[reducelr])

#compute the training time
print('Training time: %s' % (time.time()-t))
# Out:
# Epoch 1/100
# 82/82 ━━━━━━━━━━━━━━━━━━━━ 141s 1s/step - accuracy: 0.4811 - loss: 1.2200 - val_accuracy: 0.7780 - val_loss: 0.6284 - learning_rate: 1.0000e-04
# Epoch 2/100
# 82/82 ━━━━━━━━━━━━━━━━━━━━ 54s 658ms/step - accuracy: 0.7445 - loss: 0.6567 - val_accuracy: 0.8538 - val_loss: 0.4548 - learning_rate: 1.0000e-04
# Epoch 3/100
# 82/82 ━━━━━━━━━━━━━━━━━━━━ 56s 678ms/step - accuracy: 0.8113 - loss: 0.5095 - val_accuracy: 0.8773 - val_loss: 0.3921 - learning_rate: 1.0000e-04
# Epoch 4/100
# 82/82 ━━━━━━━━━━━━━━━━━━━━ 55s 676ms/step - accuracy: 0.8196 - loss: 0.4563 - val_accuracy: 0.9079 - val_loss: 0.3364 - learning_rate: 1.0000e-04
# Epoch 5/100
# 82/82 ━━━━━━━━━━━━━━━━━━━━ 55s 673ms/step - accuracy: 0.8522 - loss: 0.4139 - val_accuracy: 0.8791 - val_loss: 0.3367 - learning_rate: 1.0000e-04
# Epoch 6/100
# 82/82 ━━━━━━━━━━━━━━━━━━━━ 54s 656ms/step - accuracy: 0.8645 - loss: 0.3599 - val_accuracy: 0.9188 - val_loss: 0.2827 - learning_rate: 1.0000e-04
# Epoch 7/100
# 82/82 ━━━━━━━━━━━━━━━━━━━━ 55s 676ms/step - accuracy: 0.8666 - loss: 0.3575 - val_accuracy: 0.9386 - val_loss: 0.2374 - learning_rate: 1.0000e-04
# Epoch 8/100
# 82/82 ━━━━━━━━━━━━━━━━━━━━ 54s 655ms/step - accuracy: 0.8911 - loss: 0.3201 - val_accuracy: 0.9404 - val_loss: 0.2358 - learning_rate: 1.0000e-04
# Epoch 9/100
# 82/82 ━━━━━━━━━━━━━━━━━━━━ 65s 792ms/step - accuracy: 0.8861 - loss: 0.3058 - val_accuracy: 0.9477 - val_loss: 0.2066 - learning_rate: 1.0000e-04
# Epoch 10/100
# 82/82 ━━━━━━━━━━━━━━━━━━━━ 54s 659ms/step - accuracy: 0.9040 - loss: 0.2864 - val_accuracy: 0.9513 - val_loss: 0.1941 - learning_rate: 1.0000e-04
# Epoch 11/100
# 82/82 ━━━━━━━━━━━━━━━━━━━━ 53s 652ms/step - accuracy: 0.9205 - loss: 0.2433 - val_accuracy: 0.9621 - val_loss: 0.1614 - learning_rate: 1.0000e-04
# Epoch 12/100
# 82/82 ━━━━━━━━━━━━━━━━━━━━ 82s 658ms/step - accuracy: 0.9227 - loss: 0.2368 - val_accuracy: 0.9693 - val_loss: 0.1586 - learning_rate: 1.0000e-04
# Epoch 13/100
# 82/82 ━━━━━━━━━━━━━━━━━━━━ 55s 673ms/step - accuracy: 0.9297 - loss: 0.2124 - val_accuracy: 0.9603 - val_loss: 0.1463 - learning_rate: 1.0000e-04
# Epoch 14/100
# 82/82 ━━━━━━━━━━━━━━━━━━━━ 54s 662ms/step - accuracy: 0.9333 - loss: 0.2088 - val_accuracy: 0.9585 - val_loss: 0.1521 - learning_rate: 1.0000e-04
# Epoch 15/100
# 82/82 ━━━━━━━━━━━━━━━━━━━━ 54s 660ms/step - accuracy: 0.9394 - loss: 0.1924 - val_accuracy: 0.9819 - val_loss: 0.1255 - learning_rate: 1.0000e-04
# Epoch 16/100
# 82/82 ━━━━━━━━━━━━━━━━━━━━ 83s 674ms/step - accuracy: 0.9427 - loss: 0.1873 - val_accuracy: 0.9765 - val_loss: 0.1207 - learning_rate: 1.0000e-04
# Epoch 17/100
# 82/82 ━━━━━━━━━━━━━━━━━━━━ 81s 670ms/step - accuracy: 0.9477 - loss: 0.1780 - val_accuracy: 0.9729 - val_loss: 0.1202 - learning_rate: 1.0000e-04
# Epoch 18/100
# 82/82 ━━━━━━━━━━━━━━━━━━━━ 54s 654ms/step - accuracy: 0.9557 - loss: 0.1593 - val_accuracy: 0.9693 - val_loss: 0.1139 - learning_rate: 1.0000e-04
# Epoch 19/100
# 82/82 ━━━━━━━━━━━━━━━━━━━━ 55s 667ms/step - accuracy: 0.9512 - loss: 0.1606 - val_accuracy: 0.9729 - val_loss: 0.1021 - learning_rate: 1.0000e-04
# Epoch 20/100
# 82/82 ━━━━━━━━━━━━━━━━━━━━ 0s 542ms/step - accuracy: 0.9525 - loss: 0.1514
# Epoch 20: ReduceLROnPlateau reducing learning rate to 3.1622775802825264e-05.
# 82/82 ━━━━━━━━━━━━━━━━━━━━ 54s 653ms/step - accuracy: 0.9524 - loss: 0.1515 - val_accuracy: 0.9765 - val_loss: 0.0974 - learning_rate: 1.0000e-04
# Epoch 21/100
# 82/82 ━━━━━━━━━━━━━━━━━━━━ 55s 670ms/step - accuracy: 0.9546 - loss: 0.1439 - val_accuracy: 0.9874 - val_loss: 0.0830 - learning_rate: 3.1623e-05
# Epoch 22/100
# 82/82 ━━━━━━━━━━━━━━━━━━━━ 55s 674ms/step - accuracy: 0.9655 - loss: 0.1339 - val_accuracy: 0.9874 - val_loss: 0.0804 - learning_rate: 3.1623e-05
# Epoch 23/100
# 82/82 ━━━━━━━━━━━━━━━━━━━━ 81s 665ms/step - accuracy: 0.9564 - loss: 0.1403 - val_accuracy: 0.9819 - val_loss: 0.0822 - learning_rate: 3.1623e-05
# Epoch 24/100
# 82/82 ━━━━━━━━━━━━━━━━━━━━ 82s 668ms/step - accuracy: 0.9630 - loss: 0.1289 - val_accuracy: 0.9892 - val_loss: 0.0802 - learning_rate: 3.1623e-05
# Epoch 25/100
# 82/82 ━━━━━━━━━━━━━━━━━━━━ 54s 652ms/step - accuracy: 0.9681 - loss: 0.1269 - val_accuracy: 0.9856 - val_loss: 0.0748 - learning_rate: 3.1623e-05
# Epoch 26/100
# 82/82 ━━━━━━━━━━━━━━━━━━━━ 84s 680ms/step - accuracy: 0.9609 - loss: 0.1252 - val_accuracy: 0.9838 - val_loss: 0.0766 - learning_rate: 3.1623e-05
# Epoch 27/100
# 82/82 ━━━━━━━━━━━━━━━━━━━━ 80s 652ms/step - accuracy: 0.9585 - loss: 0.1247 - val_accuracy: 0.9856 - val_loss: 0.0755 - learning_rate: 3.1623e-05
# Epoch 28/100
# 82/82 ━━━━━━━━━━━━━━━━━━━━ 55s 677ms/step - accuracy: 0.9617 - loss: 0.1319 - val_accuracy: 0.9856 - val_loss: 0.0771 - learning_rate: 3.1623e-05
# Epoch 29/100
# 82/82 ━━━━━━━━━━━━━━━━━━━━ 0s 552ms/step - accuracy: 0.9684 - loss: 0.1149
# Epoch 29: ReduceLROnPlateau reducing learning rate to 9.999999259090306e-06.
# 82/82 ━━━━━━━━━━━━━━━━━━━━ 54s 659ms/step - accuracy: 0.9684 - loss: 0.1150 - val_accuracy: 0.9892 - val_loss: 0.0770 - learning_rate: 3.1623e-05
# Epoch 30/100
# 82/82 ━━━━━━━━━━━━━━━━━━━━ 55s 669ms/step - accuracy: 0.9681 - loss: 0.1121 - val_accuracy: 0.9892 - val_loss: 0.0750 - learning_rate: 1.0000e-05
# Epoch 31/100
# 82/82 ━━━━━━━━━━━━━━━━━━━━ 54s 658ms/step - accuracy: 0.9689 - loss: 0.1222 - val_accuracy: 0.9874 - val_loss: 0.0664 - learning_rate: 1.0000e-05
# Epoch 32/100
# 82/82 ━━━━━━━━━━━━━━━━━━━━ 83s 677ms/step - accuracy: 0.9681 - loss: 0.1122 - val_accuracy: 0.9819 - val_loss: 0.0699 - learning_rate: 1.0000e-05
# Epoch 33/100
# 82/82 ━━━━━━━━━━━━━━━━━━━━ 54s 654ms/step - accuracy: 0.9605 - loss: 0.1204 - val_accuracy: 0.9892 - val_loss: 0.0698 - learning_rate: 1.0000e-05
# Epoch 34/100
# 82/82 ━━━━━━━━━━━━━━━━━━━━ 0s 549ms/step - accuracy: 0.9670 - loss: 0.1206
# Epoch 34: ReduceLROnPlateau reducing learning rate to 3.162277292675049e-06.
# 82/82 ━━━━━━━━━━━━━━━━━━━━ 55s 669ms/step - accuracy: 0.9670 - loss: 0.1206 - val_accuracy: 0.9892 - val_loss: 0.0732 - learning_rate: 1.0000e-05
# Epoch 35/100
# 82/82 ━━━━━━━━━━━━━━━━━━━━ 53s 653ms/step - accuracy: 0.9670 - loss: 0.1128 - val_accuracy: 0.9910 - val_loss: 0.0642 - learning_rate: 3.1623e-06
# Epoch 36/100
# 82/82 ━━━━━━━━━━━━━━━━━━━━ 55s 675ms/step - accuracy: 0.9710 - loss: 0.1081 - val_accuracy: 0.9928 - val_loss: 0.0622 - learning_rate: 3.1623e-06
# Epoch 37/100
# 82/82 ━━━━━━━━━━━━━━━━━━━━ 55s 677ms/step - accuracy: 0.9654 - loss: 0.1181 - val_accuracy: 0.9874 - val_loss: 0.0712 - learning_rate: 3.1623e-06
# Epoch 38/100
# 82/82 ━━━━━━━━━━━━━━━━━━━━ 55s 668ms/step - accuracy: 0.9694 - loss: 0.1163 - val_accuracy: 0.9892 - val_loss: 0.0651 - learning_rate: 3.1623e-06
# Epoch 39/100
# 82/82 ━━━━━━━━━━━━━━━━━━━━ 53s 653ms/step - accuracy: 0.9657 - loss: 0.1120 - val_accuracy: 0.9910 - val_loss: 0.0650 - learning_rate: 3.1623e-06
# Epoch 40/100
# 82/82 ━━━━━━━━━━━━━━━━━━━━ 55s 669ms/step - accuracy: 0.9714 - loss: 0.1130 - val_accuracy: 0.9928 - val_loss: 0.0657 - learning_rate: 3.1623e-06
# Epoch 41/100
# 82/82 ━━━━━━━━━━━━━━━━━━━━ 0s 537ms/step - accuracy: 0.9706 - loss: 0.1071
# Epoch 41: ReduceLROnPlateau reducing learning rate to 9.999999115286567e-07.
# 82/82 ━━━━━━━━━━━━━━━━━━━━ 54s 656ms/step - accuracy: 0.9706 - loss: 0.1071 - val_accuracy: 0.9856 - val_loss: 0.0650 - learning_rate: 3.1623e-06
# Epoch 42/100
# 82/82 ━━━━━━━━━━━━━━━━━━━━ 55s 674ms/step - accuracy: 0.9660 - loss: 0.1097 - val_accuracy: 0.9910 - val_loss: 0.0658 - learning_rate: 1.0000e-06
# Epoch 43/100
# 82/82 ━━━━━━━━━━━━━━━━━━━━ 54s 659ms/step - accuracy: 0.9725 - loss: 0.1057 - val_accuracy: 0.9819 - val_loss: 0.0680 - learning_rate: 1.0000e-06
# Epoch 44/100
# 82/82 ━━━━━━━━━━━━━━━━━━━━ 55s 672ms/step - accuracy: 0.9711 - loss: 0.1063 - val_accuracy: 0.9946 - val_loss: 0.0579 - learning_rate: 1.0000e-06
# Epoch 45/100
# 82/82 ━━━━━━━━━━━━━━━━━━━━ 56s 679ms/step - accuracy: 0.9739 - loss: 0.1034 - val_accuracy: 0.9928 - val_loss: 0.0660 - learning_rate: 1.0000e-06
# Epoch 46/100
# 82/82 ━━━━━━━━━━━━━━━━━━━━ 54s 657ms/step - accuracy: 0.9689 - loss: 0.1186 - val_accuracy: 0.9928 - val_loss: 0.0639 - learning_rate: 1.0000e-06
# Epoch 47/100
# 82/82 ━━━━━━━━━━━━━━━━━━━━ 55s 670ms/step - accuracy: 0.9667 - loss: 0.1096 - val_accuracy: 0.9892 - val_loss: 0.0585 - learning_rate: 1.0000e-06
# Epoch 48/100
# 82/82 ━━━━━━━━━━━━━━━━━━━━ 54s 657ms/step - accuracy: 0.9645 - loss: 0.1110 - val_accuracy: 0.9874 - val_loss: 0.0629 - learning_rate: 1.0000e-06
# Epoch 49/100
# 82/82 ━━━━━━━━━━━━━━━━━━━━ 0s 555ms/step - accuracy: 0.9704 - loss: 0.1116
# Epoch 49: ReduceLROnPlateau reducing learning rate to 3.1622772926750485e-07.
# 82/82 ━━━━━━━━━━━━━━━━━━━━ 55s 676ms/step - accuracy: 0.9704 - loss: 0.1116 - val_accuracy: 0.9892 - val_loss: 0.0596 - learning_rate: 1.0000e-06
# Epoch 50/100
# 82/82 ━━━━━━━━━━━━━━━━━━━━ 54s 659ms/step - accuracy: 0.9708 - loss: 0.1103 - val_accuracy: 0.9910 - val_loss: 0.0662 - learning_rate: 3.1623e-07
# Epoch 51/100
# 82/82 ━━━━━━━━━━━━━━━━━━━━ 54s 664ms/step - accuracy: 0.9757 - loss: 0.1045 - val_accuracy: 0.9856 - val_loss: 0.0687 - learning_rate: 3.1623e-07
# Epoch 52/100
# 82/82 ━━━━━━━━━━━━━━━━━━━━ 54s 656ms/step - accuracy: 0.9678 - loss: 0.1124 - val_accuracy: 0.9928 - val_loss: 0.0613 - learning_rate: 3.1623e-07
# Epoch 53/100
# 82/82 ━━━━━━━━━━━━━━━━━━━━ 55s 674ms/step - accuracy: 0.9721 - loss: 0.1086 - val_accuracy: 0.9892 - val_loss: 0.0720 - learning_rate: 3.1623e-07
# Epoch 54/100
# 82/82 ━━━━━━━━━━━━━━━━━━━━ 0s 542ms/step - accuracy: 0.9717 - loss: 0.1031
# Epoch 54: ReduceLROnPlateau reducing learning rate to 1e-07.
# 82/82 ━━━━━━━━━━━━━━━━━━━━ 55s 669ms/step - accuracy: 0.9717 - loss: 0.1032 - val_accuracy: 0.9946 - val_loss: 0.0629 - learning_rate: 3.1623e-07
# Epoch 55/100
# 82/82 ━━━━━━━━━━━━━━━━━━━━ 55s 666ms/step - accuracy: 0.9713 - loss: 0.1063 - val_accuracy: 0.9892 - val_loss: 0.0640 - learning_rate: 1.0000e-07
# Epoch 56/100
# 82/82 ━━━━━━━━━━━━━━━━━━━━ 53s 648ms/step - accuracy: 0.9717 - loss: 0.1103 - val_accuracy: 0.9892 - val_loss: 0.0661 - learning_rate: 1.0000e-07
# Epoch 57/100
# 82/82 ━━━━━━━━━━━━━━━━━━━━ 54s 663ms/step - accuracy: 0.9707 - loss: 0.1102 - val_accuracy: 0.9928 - val_loss: 0.0652 - learning_rate: 1.0000e-07
# Epoch 58/100
# 82/82 ━━━━━━━━━━━━━━━━━━━━ 53s 653ms/step - accuracy: 0.9668 - loss: 0.1176 - val_accuracy: 0.9874 - val_loss: 0.0615 - learning_rate: 1.0000e-07
# Epoch 59/100
# 82/82 ━━━━━━━━━━━━━━━━━━━━ 54s 665ms/step - accuracy: 0.9687 - loss: 0.1069 - val_accuracy: 0.9856 - val_loss: 0.0713 - learning_rate: 1.0000e-07
# Epoch 60/100
# 82/82 ━━━━━━━━━━━━━━━━━━━━ 53s 650ms/step - accuracy: 0.9660 - loss: 0.1125 - val_accuracy: 0.9892 - val_loss: 0.0677 - learning_rate: 1.0000e-07
# Epoch 61/100
# 82/82 ━━━━━━━━━━━━━━━━━━━━ 55s 671ms/step - accuracy: 0.9650 - loss: 0.1168 - val_accuracy: 0.9892 - val_loss: 0.0649 - learning_rate: 1.0000e-07
# Epoch 62/100
# 82/82 ━━━━━━━━━━━━━━━━━━━━ 54s 662ms/step - accuracy: 0.9677 - loss: 0.1141 - val_accuracy: 0.9892 - val_loss: 0.0713 - learning_rate: 1.0000e-07
# Epoch 63/100
# 82/82 ━━━━━━━━━━━━━━━━━━━━ 55s 667ms/step - accuracy: 0.9731 - loss: 0.0994 - val_accuracy: 0.9928 - val_loss: 0.0637 - learning_rate: 1.0000e-07
# Epoch 64/100
# 82/82 ━━━━━━━━━━━━━━━━━━━━ 55s 676ms/step - accuracy: 0.9610 - loss: 0.1163 - val_accuracy: 0.9892 - val_loss: 0.0641 - learning_rate: 1.0000e-07
# Epoch 65/100
# 82/82 ━━━━━━━━━━━━━━━━━━━━ 81s 663ms/step - accuracy: 0.9790 - loss: 0.1018 - val_accuracy: 0.9892 - val_loss: 0.0617 - learning_rate: 1.0000e-07
# Epoch 66/100
# 82/82 ━━━━━━━━━━━━━━━━━━━━ 54s 655ms/step - accuracy: 0.9752 - loss: 0.1057 - val_accuracy: 0.9928 - val_loss: 0.0627 - learning_rate: 1.0000e-07
# Epoch 67/100
# 82/82 ━━━━━━━━━━━━━━━━━━━━ 54s 665ms/step - accuracy: 0.9641 - loss: 0.1164 - val_accuracy: 0.9910 - val_loss: 0.0613 - learning_rate: 1.0000e-07
# Epoch 68/100
# 82/82 ━━━━━━━━━━━━━━━━━━━━ 81s 656ms/step - accuracy: 0.9732 - loss: 0.0962 - val_accuracy: 0.9910 - val_loss: 0.0605 - learning_rate: 1.0000e-07
# Epoch 69/100
# 82/82 ━━━━━━━━━━━━━━━━━━━━ 83s 666ms/step - accuracy: 0.9683 - loss: 0.1075 - val_accuracy: 0.9928 - val_loss: 0.0638 - learning_rate: 1.0000e-07
# Epoch 70/100
# 82/82 ━━━━━━━━━━━━━━━━━━━━ 56s 680ms/step - accuracy: 0.9748 - loss: 0.1013 - val_accuracy: 0.9819 - val_loss: 0.0657 - learning_rate: 1.0000e-07
# Epoch 71/100
# 82/82 ━━━━━━━━━━━━━━━━━━━━ 55s 671ms/step - accuracy: 0.9748 - loss: 0.1005 - val_accuracy: 0.9856 - val_loss: 0.0658 - learning_rate: 1.0000e-07
# Epoch 72/100
# 82/82 ━━━━━━━━━━━━━━━━━━━━ 56s 690ms/step - accuracy: 0.9655 - loss: 0.1148 - val_accuracy: 0.9892 - val_loss: 0.0647 - learning_rate: 1.0000e-07
# Epoch 73/100
# 82/82 ━━━━━━━━━━━━━━━━━━━━ 80s 670ms/step - accuracy: 0.9673 - loss: 0.1155 - val_accuracy: 0.9910 - val_loss: 0.0619 - learning_rate: 1.0000e-07
# Epoch 74/100
# 82/82 ━━━━━━━━━━━━━━━━━━━━ 56s 685ms/step - accuracy: 0.9765 - loss: 0.1026 - val_accuracy: 0.9910 - val_loss: 0.0619 - learning_rate: 1.0000e-07
# Epoch 75/100
# 82/82 ━━━━━━━━━━━━━━━━━━━━ 55s 671ms/step - accuracy: 0.9697 - loss: 0.1150 - val_accuracy: 0.9838 - val_loss: 0.0683 - learning_rate: 1.0000e-07
# Epoch 76/100
# 82/82 ━━━━━━━━━━━━━━━━━━━━ 56s 679ms/step - accuracy: 0.9672 - loss: 0.1149 - val_accuracy: 0.9874 - val_loss: 0.0673 - learning_rate: 1.0000e-07
# Epoch 77/100
# 82/82 ━━━━━━━━━━━━━━━━━━━━ 55s 668ms/step - accuracy: 0.9671 - loss: 0.1103 - val_accuracy: 0.9946 - val_loss: 0.0593 - learning_rate: 1.0000e-07
# Epoch 78/100
# 82/82 ━━━━━━━━━━━━━━━━━━━━ 57s 692ms/step - accuracy: 0.9710 - loss: 0.1058 - val_accuracy: 0.9874 - val_loss: 0.0636 - learning_rate: 1.0000e-07
# Epoch 79/100
# 82/82 ━━━━━━━━━━━━━━━━━━━━ 82s 690ms/step - accuracy: 0.9685 - loss: 0.1089 - val_accuracy: 0.9892 - val_loss: 0.0649 - learning_rate: 1.0000e-07
# Epoch 80/100
# 82/82 ━━━━━━━━━━━━━━━━━━━━ 55s 668ms/step - accuracy: 0.9727 - loss: 0.1118 - val_accuracy: 0.9874 - val_loss: 0.0656 - learning_rate: 1.0000e-07
# Epoch 81/100
# 82/82 ━━━━━━━━━━━━━━━━━━━━ 55s 675ms/step - accuracy: 0.9747 - loss: 0.1096 - val_accuracy: 0.9892 - val_loss: 0.0691 - learning_rate: 1.0000e-07
# Epoch 82/100
# 82/82 ━━━━━━━━━━━━━━━━━━━━ 54s 659ms/step - accuracy: 0.9692 - loss: 0.1123 - val_accuracy: 0.9892 - val_loss: 0.0634 - learning_rate: 1.0000e-07
# Epoch 83/100
# 82/82 ━━━━━━━━━━━━━━━━━━━━ 55s 675ms/step - accuracy: 0.9748 - loss: 0.1045 - val_accuracy: 0.9892 - val_loss: 0.0645 - learning_rate: 1.0000e-07
# Epoch 84/100
# 82/82 ━━━━━━━━━━━━━━━━━━━━ 55s 672ms/step - accuracy: 0.9758 - loss: 0.1041 - val_accuracy: 0.9946 - val_loss: 0.0617 - learning_rate: 1.0000e-07
# Epoch 85/100
# 82/82 ━━━━━━━━━━━━━━━━━━━━ 82s 677ms/step - accuracy: 0.9689 - loss: 0.1095 - val_accuracy: 0.9765 - val_loss: 0.0761 - learning_rate: 1.0000e-07
# Epoch 86/100
# 82/82 ━━━━━━━━━━━━━━━━━━━━ 55s 668ms/step - accuracy: 0.9677 - loss: 0.1205 - val_accuracy: 0.9928 - val_loss: 0.0601 - learning_rate: 1.0000e-07
# Epoch 87/100
# 82/82 ━━━━━━━━━━━━━━━━━━━━ 56s 680ms/step - accuracy: 0.9635 - loss: 0.1273 - val_accuracy: 0.9892 - val_loss: 0.0661 - learning_rate: 1.0000e-07
# Epoch 88/100
# 82/82 ━━━━━━━━━━━━━━━━━━━━ 54s 658ms/step - accuracy: 0.9669 - loss: 0.1114 - val_accuracy: 0.9910 - val_loss: 0.0607 - learning_rate: 1.0000e-07
# Epoch 89/100
# 82/82 ━━━━━━━━━━━━━━━━━━━━ 55s 671ms/step - accuracy: 0.9696 - loss: 0.1130 - val_accuracy: 0.9874 - val_loss: 0.0674 - learning_rate: 1.0000e-07
# Epoch 90/100
# 82/82 ━━━━━━━━━━━━━━━━━━━━ 54s 665ms/step - accuracy: 0.9699 - loss: 0.1083 - val_accuracy: 0.9910 - val_loss: 0.0621 - learning_rate: 1.0000e-07
# Epoch 91/100
# 82/82 ━━━━━━━━━━━━━━━━━━━━ 82s 671ms/step - accuracy: 0.9633 - loss: 0.1175 - val_accuracy: 0.9910 - val_loss: 0.0611 - learning_rate: 1.0000e-07
# Epoch 92/100
# 82/82 ━━━━━━━━━━━━━━━━━━━━ 54s 657ms/step - accuracy: 0.9715 - loss: 0.1040 - val_accuracy: 0.9874 - val_loss: 0.0619 - learning_rate: 1.0000e-07
# Epoch 93/100
# 82/82 ━━━━━━━━━━━━━━━━━━━━ 55s 669ms/step - accuracy: 0.9638 - loss: 0.1174 - val_accuracy: 0.9910 - val_loss: 0.0596 - learning_rate: 1.0000e-07
# Epoch 94/100
# 82/82 ━━━━━━━━━━━━━━━━━━━━ 56s 678ms/step - accuracy: 0.9705 - loss: 0.1113 - val_accuracy: 0.9892 - val_loss: 0.0654 - learning_rate: 1.0000e-07
# Epoch 95/100
# 82/82 ━━━━━━━━━━━━━━━━━━━━ 57s 695ms/step - accuracy: 0.9715 - loss: 0.1080 - val_accuracy: 0.9910 - val_loss: 0.0657 - learning_rate: 1.0000e-07
# Epoch 96/100
# 82/82 ━━━━━━━━━━━━━━━━━━━━ 56s 686ms/step - accuracy: 0.9723 - loss: 0.1073 - val_accuracy: 0.9928 - val_loss: 0.0607 - learning_rate: 1.0000e-07
# Epoch 97/100
# 82/82 ━━━━━━━━━━━━━━━━━━━━ 56s 679ms/step - accuracy: 0.9683 - loss: 0.1140 - val_accuracy: 0.9928 - val_loss: 0.0598 - learning_rate: 1.0000e-07
# Epoch 98/100
# 82/82 ━━━━━━━━━━━━━━━━━━━━ 55s 666ms/step - accuracy: 0.9694 - loss: 0.1070 - val_accuracy: 0.9856 - val_loss: 0.0677 - learning_rate: 1.0000e-07
# Epoch 99/100
# 82/82 ━━━━━━━━━━━━━━━━━━━━ 55s 677ms/step - accuracy: 0.9725 - loss: 0.1052 - val_accuracy: 0.9910 - val_loss: 0.0628 - learning_rate: 1.0000e-07
# Epoch 100/100
# 82/82 ━━━━━━━━━━━━━━━━━━━━ 55s 666ms/step - accuracy: 0.9687 - loss: 0.1181 - val_accuracy: 0.9838 - val_loss: 0.0680 - learning_rate: 1.0000e-07
# Training time: 5976.872408151627

# %%
 import matplotlib.pyplot as plt
# Config the matplotlib backend as plotting inline in IPython
# %matplotlib inline

acc = history.history['val_accuracy']
val_acc = history.history['accuracy']
val_loss = history.history['loss']
loss = history.history['val_loss']
epochs = range(1, len(acc) + 1)
plt.style.use('seaborn-whitegrid') # Use a specific seaborn style like 'seaborn-whitegrid'

plt.plot(epochs, acc, label='Training acc')
plt.plot(epochs, val_acc, label='Validation acc')
plt.xlabel('Num of Epochs')
plt.ylabel('Accuracy')
plt.title(' DenseNet201 Training vs validation accuracy ')
plt.legend()
plt.figure()
plt.plot(epochs, loss, label='Training loss')
plt.plot(epochs, val_loss, label='Validation loss')
plt.title('DenseNet201 Training vs validation loss ')
plt.xlabel('Num of Epochs')
plt.ylabel('Loss')
plt.legend()
plt.show()
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# /usr/local/lib/python3.11/dist-packages/matplotlib/style/core.py in use(style)
#     128             try:
# --> 129                 style = _rc_params_in_file(style)
#     130             except OSError as err:
#
# /usr/local/lib/python3.11/dist-packages/matplotlib/__init__.py in _rc_params_in_file(fname, transform, fail_on_error)
#     902     rc_temp = {}
# --> 903     with _open_file_or_url(fname) as fd:
#     904         try:
#
# /usr/lib/python3.11/contextlib.py in __enter__(self)
#     136         try:
# --> 137             return next(self.gen)
#     138         except StopIteration:
#
# /usr/local/lib/python3.11/dist-packages/matplotlib/__init__.py in _open_file_or_url(fname)
#     879         fname = os.path.expanduser(fname)
# --> 880         with open(fname, encoding='utf-8') as f:
#     881             yield f
#
# FileNotFoundError: [Errno 2] No such file or directory: 'seaborn-whitegrid'
#
# The above exception was the direct cause of the following exception:
#
# OSError                                   Traceback (most recent call last)
# <ipython-input-21-4205857c180c> in <cell line: 0>()
#       8 loss = history.history['val_loss']
#       9 epochs = range(1, len(acc) + 1)
# ---> 10 plt.style.use('seaborn-whitegrid') # Use a specific seaborn style like 'seaborn-whitegrid'
#      11
#      12 plt.plot(epochs, acc, label='Training acc')
#
# /usr/local/lib/python3.11/dist-packages/matplotlib/style/core.py in use(style)
#     129                 style = _rc_params_in_file(style)
#     130             except OSError as err:
# --> 131                 raise OSError(
#     132                     f"{style!r} is not a valid package style, path of style "
#     133                     f"file, URL of style file, or library style name (library "
#
# OSError: 'seaborn-whitegrid' is not a valid package style, path of style file, URL of style file, or library style name (library styles are listed in `style.available`)

# %%
 import matplotlib.pyplot as plt
# Config the matplotlib backend as plotting inline in IPython
# %matplotlib inline

acc = history.history['val_accuracy']
val_acc = history.history['accuracy']
val_loss = history.history['loss']
loss = history.history['val_loss']
epochs = range(1, len(acc) + 1)
plt.style.use('seaborn')

plt.plot(epochs, acc, label='Training acc')
plt.plot(epochs, val_acc, label='Validation acc')
plt.xlabel('Num of Epochs')
plt.ylabel('Accuracy')
plt.title(' MobileNetV2 Training vs validation accuracy ')
plt.legend()
plt.figure()
plt.plot(epochs, loss, label='Training loss')
plt.plot(epochs, val_loss, label='Validation loss')
plt.title('MobileNetV2 Training vs validation loss ')
plt.xlabel('Num of Epochs')
plt.ylabel('Loss')
plt.legend()
plt.show()
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# /usr/local/lib/python3.11/dist-packages/matplotlib/style/core.py in use(style)
#     128             try:
# --> 129                 style = _rc_params_in_file(style)
#     130             except OSError as err:
#
# /usr/local/lib/python3.11/dist-packages/matplotlib/__init__.py in _rc_params_in_file(fname, transform, fail_on_error)
#     902     rc_temp = {}
# --> 903     with _open_file_or_url(fname) as fd:
#     904         try:
#
# /usr/lib/python3.11/contextlib.py in __enter__(self)
#     136         try:
# --> 137             return next(self.gen)
#     138         except StopIteration:
#
# /usr/local/lib/python3.11/dist-packages/matplotlib/__init__.py in _open_file_or_url(fname)
#     879         fname = os.path.expanduser(fname)
# --> 880         with open(fname, encoding='utf-8') as f:
#     881             yield f
#
# FileNotFoundError: [Errno 2] No such file or directory: 'seaborn'
#
# The above exception was the direct cause of the following exception:
#
# OSError                                   Traceback (most recent call last)
# <ipython-input-30-dc8e505fada0> in <cell line: 0>()
#       8 loss = history.history['val_loss']
#       9 epochs = range(1, len(acc) + 1)
# ---> 10 plt.style.use('seaborn')
#      11
#      12 plt.plot(epochs, acc, label='Training acc')
#
# /usr/local/lib/python3.11/dist-packages/matplotlib/style/core.py in use(style)
#     129                 style = _rc_params_in_file(style)
#     130             except OSError as err:
# --> 131                 raise OSError(
#     132                     f"{style!r} is not a valid package style, path of style "
#     133                     f"file, URL of style file, or library style name (library "
#
# OSError: 'seaborn' is not a valid package style, path of style file, URL of style file, or library style name (library styles are listed in `style.available`)

# %%
import matplotlib.pyplot as plt

# Ensure history is available
if 'history' not in globals():
    raise ValueError("The variable 'history' is not defined. Ensure model.fit() has been run.")

# Use correct Matplotlib style
plt.style.use("seaborn-v0_8-whitegrid")

# Extract values safely
acc = history.history.get('accuracy', [])
val_acc = history.history.get('val_accuracy', [])
loss = history.history.get('loss', [])
val_loss = history.history.get('val_loss', [])

# Define epochs
epochs = range(1, len(acc) + 1)

# Check if data exists
if not acc or not loss:
    raise ValueError("Empty training history. Ensure model.fit() has been executed.")

# Plot Accuracy
plt.figure(figsize=(8, 5))
plt.plot(epochs, acc, label='Training Accuracy', marker='o')
plt.plot(epochs, val_acc, label='Validation Accuracy', marker='s')
plt.xlabel('Number of Epochs')
plt.ylabel('Accuracy')
plt.title('DenseNet201 Training vs Validation Accuracy')
plt.legend()
plt.grid(True)

# Plot Loss
plt.figure(figsize=(8, 5))
plt.plot(epochs, loss, label='Training Loss', marker='o')
plt.plot(epochs, val_loss, label='Validation Loss', marker='s')
plt.xlabel('Number of Epochs')
plt.ylabel('Loss')
plt.title('DenseNet201 Training vs Validation Loss')
plt.legend()
plt.grid(True)

# Show plots
plt.show()

# %%
model.save("/content/drive/MyDrive/Diabetic Foot ulcer/deployment_model.h5")
print("model saved!!!")
# Out:
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.
# model saved!!!

# %%
import numpy as np
accuracy = np.array(acc)
print(' Training Accuracy of model is      :   '  , accuracy[-1]*100,'%' )

val_accuracy = np.array(val_acc)
print('  Validation  Accuracy of model is      :   '  , val_accuracy[-1]*100,'%' )

t_loss = np.array(loss)
print('training   loss of   model   is     :   ' , t_loss[-1]*100,'%')
val_loss = np.array(val_loss)
print('Validation  loss of   model  is     :   ' , val_loss[-1]*100,'%')
# Out:
#  Training Accuracy of model is      :    97.15384840965271 %
#   Validation  Accuracy of model is      :    98.37545156478882 %
# training   loss of   model   is     :    11.474362015724182 %
# Validation  loss of   model  is     :    6.798999011516571 %

# %%
data_dir1 = "/content/drive/MyDrive/Diabetic Foot ulcer/Testing"

datagen = ImageDataGenerator(
        shear_range=0.1,
        zoom_range=0.1,
        brightness_range=[0.9,1.1],
        horizontal_flip=True,
        preprocessing_function=preprocess_input
)
val_suffle=False

test_generator = datagen.flow_from_directory(
        data_dir1,
        target_size=(224, 224),
        batch_size=32,
        class_mode='categorical',
        shuffle=False,

        #subset="test"
)
score = model.evaluate(test_generator, verbose=1)
print(score)
# Out:
# Found 555 images belonging to 5 classes.
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 226s 13s/step - accuracy: 0.9909 - loss: 0.0344
# [0.059147611260414124, 0.9819819927215576]

# %%
from sklearn.metrics import roc_auc_score,roc_curve,auc
import seaborn as sns
import pandas as pd
import numpy as np
import seaborn as sn
def plot_multiclass_roc(y_pred, y_test, n_classes,class_label, figsize=(17, 6)):

    # structures
    fpr = dict()
    tpr = dict()
    roc_auc = dict()

    # calculate dummies once
    for i in range(n_classes):
        fpr[i], tpr[i], _ = roc_curve(y_test.iloc[:, i], y_pred[:, i])
        roc_auc[i] = auc(fpr[i], tpr[i])

    # roc for each class
    fig, ax = plt.subplots(figsize=figsize)
    ax.plot([0, 1], [0, 1], 'k--')
    ax.set_xlim([0.0, 1.0])
    ax.set_ylim([0.0, 1.05])
    ax.set_xlabel('False Positive Rate')
    ax.set_ylabel('True Positive Rate')
    ax.set_title('Receiver operating characteristic example')
    for i,j in enumerate(class_label):
        print(i,j)
        ax.plot(fpr[i], tpr[i], label='ROC curve (area = {}) for label {}'.format(np.round(roc_auc[i],2),j))
    ax.legend(loc="best")
    ax.grid(alpha=.4)
    sns.despine()
    plt.show()

# %%
#Alexnet_model.evaluate(valid_set,steps=valid_set.n//batch_size)
#valid_set.reset()

model.evaluate(test,steps=test_generator.n//batch_size)
test_generator.reset()

y_pred = model.predict(test_generator, steps=int(np.ceil(test_generator.n / batch_size)), verbose=1)
class_label=list(test_generator.class_indices.keys())


if val_suffle==True:
  per = np.random.permutation(test_generator.n)
  test_generator.index_array = per
  y_true = test_generator.classes[per]
else:
  y_true = test_generator.classes


plot_multiclass_roc(y_pred, pd.get_dummies(y_true), n_classes=5, class_label=class_label, figsize=(10, 5))
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-42-3a648e56ceee> in <cell line: 0>()
#       2 #valid_set.reset()
#       3
# ----> 4 model.evaluate(test,steps=test_generator.n//batch_size)
#       5 test_generator.reset()
#       6
#
# NameError: name 'test' is not defined

# %%
score = model.evaluate(test_generator, verbose=1)
# Out:
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 10s 532ms/step - accuracy: 0.9944 - loss: 0.0334

# %%
test_generator.reset()
predictions = model.predict(test_generator, steps=len(test_generator))
y = np.argmax(predictions, axis=1)

print('Classification Report')
cr = classification_report(y_true=test_generator.classes, y_pred=y, target_names=test_generator.class_indices)
print(cr)
# Out:
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 51s 2s/step
# Classification Report
#                                  precision    recall  f1-score   support
#
#             Grade_0 Intact skin       1.00      1.00      1.00       111
#       Grade_1 Superficial ulcer       0.99      1.00      1.00       111
#    Grade_2 Deep ulcer to tendon       0.97      0.96      0.97       111
# Grade_3 Deep ulcer with abscess       0.98      0.97      0.98       111
#     Grade_4 Whole foot gangrene       0.99      1.00      1.00       111
#
#                        accuracy                           0.99       555
#                       macro avg       0.99      0.99      0.99       555
#                    weighted avg       0.99      0.99      0.99       555

# %%
import seaborn as sns
from sklearn.metrics import confusion_matrix, classification_report
classes=['Grade_0 Intact skin', 'Grade_1 Superficial ulcer', 'Grade_2 Deep ulcer to tendon','Grade_3 Deep ulcer with absces','Grade_4 Whole foot gangrene']

preds=model.predict(test_generator)
y_pred=[]
y_true=[]
for i, p in enumerate(preds):
    y_pred.append(np.argmax(p))
    y_true.append(test_generator.labels[i])
y_pred=np.array(y_pred)
y_true=np.array(y_true)
cm = confusion_matrix(y_true, y_pred )
clr = classification_report(y_true, y_pred, target_names=classes)
length=len(classes)
plt.figure(figsize=(8, 8))
sns.heatmap(cm, annot=True, vmin=0, fmt='g', cmap='Blues', cbar=False)
plt.xticks(np.arange(length)+.5, classes, rotation= 90)
plt.yticks(np.arange(length)+.5, classes, rotation=0)
plt.xlabel("Predicted")
plt.ylabel("Actual ")
plt.title("Confusion Matrix")
plt.show()
# Out:
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 16s 901ms/step
